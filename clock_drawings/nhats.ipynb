# %%
import pandas as pd
import numpy as np

# %%
clock_df = pd.read_sas("NHATS_R14_Beta_Release_SAS/NHATS_Round_14B_SP_File.sas7bdat")[['spid', 'cg14dclkdlnn']]
clock_df = clock_df[clock_df['cg14dclkdlnn'] >= 0]
clock_df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 clock_df = pd.read_sas("NHATS_R14_Beta_Release_SAS/NHATS_Round_14B_SP_File.sas7bdat")[['spid', 'cg14dclkdlnn']]
#       2 clock_df = clock_df[clock_df['cg14dclkdlnn'] >= 0]
#       3 clock_df
#
# File ~/Desktop/CogniPlayML/.venv/lib/python3.13/site-packages/pandas/io/sas/sasreader.py:183, in read_sas(filepath_or_buffer, format, index, encoding, chunksize, iterator, compression)
#     180 elif format.lower() == "sas7bdat":
#     181     from pandas.io.sas.sas7bdat import SAS7BDATReader
# --> 183     reader = SAS7BDATReader(
#     184         filepath_or_buffer,
#     185         index=index,
#     186         encoding=encoding,
#     187         chunksize=chunksize,
#     188         compression=compression,
#     189     )
#     190 else:
#     191     raise ValueError("unknown SAS format")
#
# ...
